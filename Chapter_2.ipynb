# %% [markdown]
# <a href="https://colab.research.google.com/github/sxc/low-code-book-projects/blob/notebook/Chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://data.cdc.gov/api/views/55yu-xksw/rows.csv?accessType=DOWNLOAD'
heart_df = pd.read_csv(url, index_col=0)
heart_df.head()
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78792 entries, 2020 to 2020
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                78792 non-null  object
#  1   LocationDesc                78792 non-null  object
#  2   GeographicLevel             78792 non-null  object
#  3   DataSource                  78792 non-null  object
#  4   Class                       78792 non-null  object
#  5   Topic                       78792 non-null  object
#  6   Data_Value                  34430 non-null  float64
#  7   Data_Value_Unit             78792 non-null  object
#  8   Data_Value_Type             78792 non-null  object
#  9   Data_Value_Footnote_Symbol  44362 non-null  object
#  10  Data_Value_Footnote         44362 non-null  object
#  11  StratificationCategory1     78792 non-null  object
#  12  Stratification1             78792 non-null  object
# ...

# %%
heart_df = pd.read_csv('/content/heart.csv',on_bad_lines='warn',
                       engine="python")
heart_df.head()
heart_df.info()
heart_df.isnull().sum()

import seaborn as sns
sns.violinplot(x="Data_Value", y="Stratification2", data=heart_df)

sns.displot(heart_df['Data_Value'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69550 entries, 0 to 69549
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        69550 non-null  int64
#  1   LocationAbbr                69550 non-null  object
#  2   LocationDesc                69550 non-null  object
#  3   GeographicLevel             69550 non-null  object
#  4   DataSource                  69550 non-null  object
#  5   Class                       69550 non-null  object
#  6   Topic                       69550 non-null  object
#  7   Data_Value                  31169 non-null  float64
#  8   Data_Value_Unit             69549 non-null  object
#  9   Data_Value_Type             69549 non-null  object
#  10  Data_Value_Footnote_Symbol  38380 non-null  object
#  11  Data_Value_Footnote         38380 non-null  object
#  12  StratificationCategory1     69549 non-null  object
# ...
